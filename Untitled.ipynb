# %%
from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotVisibleException as NotVisible
import pandas as pd
import numpy as np
import time
import re
import concurrent.futures

# %%
#create a webdriver object and set options for headless browsing
options = Options()
options.headless = True
driver = webdriver.Chrome('./chromedriver',options=options)

# %%
#uses webdriver object to execute javascript code and get dynamically loaded webcontent
def get_js_soup(url,driver):
    driver.get(url)
    res_html = driver.execute_script('return document.body.innerHTML')
    soup = BeautifulSoup(res_html,'html.parser') #beautiful soup object to be used for parsing html content
    return soup

# %%
def scrape_categories(driver):
    categories = pd.DataFrame(columns=['category', 'url'])
    url = 'https://www.allrecipes.com/recipes/'
    soup = get_js_soup(url, driver)
    for category in soup.find_all('li', class_='carouselNav__listItem recipeCarousel__listItem'):
        category_name = category.find('div', class_='carouselNav__linkText').text
        category_url = category.find('a', class_='carouselNav__link recipeCarousel__link')['href']
        categories = categories.append({'category':category_name, 'url':category_url}, ignore_index=True)
    return categories

# %%
def scrape_recipes(url, driver, num_pages, recipes):     
    for i in range(num_pages):
        soup = get_js_soup(f'{url}?page={i}', driver)

        for recipe in soup.find_all('div', class_='component tout'):
            # Check if the recipe is a Gallary of recipes. Do not include these.
            if not recipe.find('span', class_='tout__contentFlagText'):
                recipe_name = recipe.find('a', class_='tout__titleLink')['title']
                recipe_url = recipe.find('a', class_='tout__titleLink')['href']
                recipes = recipes.append({'recipe_name':recipe_name, 'recipe_url':"https://www.allrecipes.com/" + recipe_url}, ignore_index=True)
    
    return recipes

# %%
# Loop through each category and scrape recipes
recipes = pd.DataFrame(columns=['recipe_name', 'recipe_url'])
for i in range(len(categories)):
    recipes = scrape_recipes(categories.url[i], driver, 40, recipes)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-218-b1c473005dd5> in <module>
#       2 recipes = pd.DataFrame(columns=['recipe_name', 'recipe_url'])
#       3 for i in range(len(categories)):
# ----> 4     recipes = scrape_recipes(categories.url[i], driver, 40, recipes)
#
# <ipython-input-182-a3f294b0eccc> in scrape_recipes(url, driver, num_pages, recipes)
#       1 def scrape_recipes(url, driver, num_pages, recipes):
#       2     for i in range(num_pages):
# ----> 3         soup = get_js_soup(f'{url}?page={i}', driver)
#       4
#       5         for recipe in soup.find_all('div', class_='component tout'):
#
# <ipython-input-180-5d755f3c311e> in get_js_soup(url, driver)
#       3     driver.get(url)
#       4     res_html = driver.execute_script('return document.body.innerHTML')
# ----> 5     soup = BeautifulSoup(res_html,'html.parser') #beautiful soup object to be used for parsing html content
#       6     return soup
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     360             self.reset()
#     361             try:
# --> 362                 self._feed()
#     363                 success = True
#     364                 break
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\__init__.py in _feed(self)
#     446         self.builder.reset()
#     447
# --> 448         self.builder.feed(self.markup)
#     449         # Close out any unfinished strings and close all the open tags.
#     450         self.endData()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     390         parser.soup = self.soup
#     391         try:
# --> 392             parser.feed(markup)
#     393             parser.close()
#     394         except HTMLParseError as e:
#
# ~\anaconda3\envs\mlenv\lib\html\parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~\anaconda3\envs\mlenv\lib\html\parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# ~\anaconda3\envs\mlenv\lib\html\parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\builder\_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#     151         tag = self.soup.handle_starttag(
#     152             name, None, None, attr_dict, sourceline=sourceline,
# --> 153             sourcepos=sourcepos
#     154         )
#     155         if tag and tag.is_empty_element and handle_empty_element:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos)
#     717             self, self.builder, name, namespace, nsprefix, attrs,
#     718             self.currentTag, self._most_recent_element,
# --> 719             sourceline=sourceline, sourcepos=sourcepos
#     720         )
#     721         if tag is None:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\element.py in __init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types)
#    1194             # We don't actually store the parser object: that lets extracted
#    1195             # chunks be garbage-collected.
# -> 1196             self.parser_class = parser.__class__
#    1197         if name is None:
#    1198             raise ValueError("No value provided for new tag's name.")
#
# KeyboardInterrupt:

# %%
recipes.to_csv('recipes.csv')

# %%
# There are ~500 duplicate entries in the ~18000 recipes in recipes.csv
recipes = pd.read_csv('recipes.csv', index_col=0).drop_duplicates()

# %%
recipes['rating'], recipes['ingredient'], recipes['quantity'], recipes['unit'] = np.nan, np.nan, np.nan, np.nan

# %%
recipes
# Out:
#                           recipe_name  \
# 0            Herbed Pomegranate Salsa
# 1                          Deer Jerky
# 2            Superb Sauteed Mushrooms
# 3                  Easy Apple Strudel
# 4                Seven Layer Taco Dip
# ...                               ...
# 18211  Black Bean and Rice Enchiladas
# 18213            Real Chiles Rellenos
# 18215          Slovak Stuffed Cabbage
# 18219     Authentic Mexican Picadillo
# 18228              Crispy Orange Beef
#
#                                               recipe_url
# 0      https://www.allrecipes.com//recipe/38034/herbe...
# 1      https://www.allrecipes.com//recipe/46324/deer-...
# 2      https://www.allrecipes.com//recipe/222795/supe...
# 3      https://www.allrecipes.com//recipe/47821/easy-...
# 4      https://www.allrecipes.com//recipe/19673/seven...
# ...                                                  ...
# 18211  https://www.allrecipes.com//recipe/222598/blac...
# 18213  https://www.allrecipes.com//recipe/214088/real...
# 18215  https://www.allrecipes.com//recipe/14597/slova...
# 18219  https://www.allrecipes.com//recipe/267628/auth...
# 18228  https://www.allrecipes.com//recipe/57966/crisp...
#
# [11236 rows x 2 columns]

# %%
ingredients = pd.DataFrame(columns=['recipe', 'url', 'rating', 'ingredient', 'quantity', 'unit'])

# %%
ingredients
# Out:
# Empty DataFrame
# Columns: [recipe, url, rating, ingredient, quantity, unit]
# Index: []

# %%
def scrape_ingredients(url, driver):
    soup = get_js_soup(url, driver)   
    
    recipe_name = recipes.loc[recipes.recipe_url == url, 'recipe_name'].values[0]
    
    # If a rating section exists on the recipe page
    if soup.find('span', class_='review-star-text'):
        
        # Some recipes have a rating section but have 'Unrated' rating. If this is not the case then extract the rating
        if soup.find('span', class_='review-star-text').text != 'Rating: Unrated':
            rating = soup.find('span', class_='review-star-text').text

            # ratings are input as "Rating: x.xx". Remove all but numeric value and convert to float
            rating = float(re.findall(r'\d+\.?\d*', rating)[0])
        else:
            # If a rating doesn't exist, give it a value of 0.00
            rating = 0.0
    
    for ingredients in soup.find_all('li', class_='ingredients-item'):        
        
        ingredient = ingredients.find('input', class_='checkbox-list-input')['value']        
        quantity = ingredients.find('input', class_='checkbox-list-input')['data-init-quantity']
        unit = ingredients.find('input', class_='checkbox-list-input')['data-unit']
        
        # Add data to recipes dataframe
        #ingredients.loc[recipe_num, ['recipe', 'url', 'rating', 'ingredient', 'quantity', 'unit']] = recipe_name, url, rating, ingredient, quantity, unit
        ingredients = pd.DataFrame([recipe_name, url, rating, ingredient, quanitity])
        ingredients = ingredients.append({'recipe':recipe_name, 'url':url, 'rating':rating, 'ingredient':ingredient, 'quantity':quantity, 'unit':unit}, ignore_index=True)

# %%
recipes_dict = []

# %%
def scrape_ingredients(url, driver):
    #Get the index from recipes dataframe that matches the url
    
    #index = pd.MultiIndex.from_product([[recipe_num], np.arange(0)], names=['recipe_num', 'ingredient_num'])
    #ingredients_df = pd.DataFrame(columns=['rating', 'ingredient', 'quantity', 'unit'], index=index)
    ingredients_df = pd.DataFrame(columns=['rating', 'ingredient', 'quantity', 'unit'])
    soup = get_js_soup(url, driver)   
    
    recipe_name = recipes.loc[recipes.recipe_url == url, 'recipe_name'].values[0]
    
    # If a rating section exists on the recipe page
    if soup.find('span', class_='review-star-text'):
        
        # Some recipes have a rating section but have 'Unrated' rating. If this is not the case then extract the rating
        if soup.find('span', class_='review-star-text').text != 'Rating: Unrated':
            rating = soup.find('span', class_='review-star-text').text

            # ratings are input as "Rating: x.xx". Remove all but numeric value and convert to float
            rating = float(re.findall(r'\d+\.?\d*', rating)[0])
        else:
            # If a rating doesn't exist, give it a value of 0.00
            rating = 0.0
    
    for ingredients in soup.find_all('li', class_='ingredients-item'):        
        ingredient = ingredients.find('input', class_='checkbox-list-input')['value']
        quantity = ingredients.find('input', class_='checkbox-list-input')['data-init-quantity']
        unit = ingredients.find('input', class_='checkbox-list-input')['data-unit']
        ingredients_df = ingredients_df.append({'rating':rating, 'ingredient':ingredient, 'quantity':quantity, 'unit':unit}, ignore_index=True)
        recipes_dict.append({'recipe':recipe_name, 'url':url, 'rating':rating, 'ingredient':ingredient, 'quantity':quantity, 'unit':unit})
    
    # Reindex as a multi index with the recipe as an indexer
    #recipe_num = recipes.index[recipes.recipe_url == asdf.index[0][0]][0]
    #index = pd.MultiIndex.from_product([[recipe_num], np.arange(len(ingredients_df))], names=['recipe_num', 'ingredient_num'])
    #ingredients_df = ingredients_df.set_index(index)
    recipe_name = recipes.loc[recipes.recipe_url == url, 'recipe_name'].values[0]
    
    ingredients_df['recipe_name'] = recipes.loc[recipes.recipe_url == url, 'recipe_name'].values[0]
    ingredients_df['url'] = url
    
    return recipes_dict.append({'recipe':recipe_name, 'url':url, 'rating':rating, 'ingredient':ingredient, 'quantity':quantity, 'unit':unit})

# %%
def scrape_ingredients(url, driver):
    #Get the index from recipes dataframe that matches the url
    
    #index = pd.MultiIndex.from_product([[recipe_num], np.arange(0)], names=['recipe_num', 'ingredient_num'])
    #ingredients_df = pd.DataFrame(columns=['rating', 'ingredient', 'quantity', 'unit'], index=index)
    ingredients_df = pd.DataFrame(columns=['rating', 'ingredient', 'quantity', 'unit'])
    soup = get_js_soup(url, driver)   
    
    recipe_name = recipes.loc[recipes.recipe_url == url, 'recipe_name'].values[0]
    
    # If a rating section exists on the recipe page
    if soup.find('span', class_='review-star-text'):
        
        # Some recipes have a rating section but have 'Unrated' rating. If this is not the case then extract the rating
        if soup.find('span', class_='review-star-text').text != 'Rating: Unrated':
            rating = soup.find('span', class_='review-star-text').text

            # ratings are input as "Rating: x.xx". Remove all but numeric value and convert to float
            rating = float(re.findall(r'\d+\.?\d*', rating)[0])
        else:
            # If a rating doesn't exist, give it a value of 0.00
            rating = 0.0
    
    for ingredients in soup.find_all('li', class_='ingredients-item'):        
        ingredient = ingredients.find('input', class_='checkbox-list-input')['value']
        quantity = ingredients.find('input', class_='checkbox-list-input')['data-init-quantity']
        unit = ingredients.find('input', class_='checkbox-list-input')['data-unit']
        ingredients_df = ingredients_df.append({'rating':rating, 'ingredient':ingredient, 'quantity':quantity, 'unit':unit}, ignore_index=True)
        recipes_dict.append({'recipe':recipe_name, 'url':url, 'rating':rating, 'ingredient':ingredient, 'quantity':quantity, 'unit':unit})
    
    # Reindex as a multi index with the recipe as an indexer
    #recipe_num = recipes.index[recipes.recipe_url == asdf.index[0][0]][0]
    #index = pd.MultiIndex.from_product([[recipe_num], np.arange(len(ingredients_df))], names=['recipe_num', 'ingredient_num'])
    #ingredients_df = ingredients_df.set_index(index)
    recipe_name = recipes.loc[recipes.recipe_url == url, 'recipe_name'].values[0]
    
    ingredients_df['recipe_name'] = recipes.loc[recipes.recipe_url == url, 'recipe_name'].values[0]
    ingredients_df['url'] = url
    
    return recipes_dict.append({'recipe':recipe_name, 'url':url, 'rating':rating, 'ingredient':ingredient, 'quantity':quantity, 'unit':unit})

# %%
scrape_ingredients(recipes.recipe_url[1], driver)

# %%
scrape_ingredients(recipes.recipe_url[1], driver, ingredients)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-21343c8b1bfd> in <module>
# ----> 1 scrape_ingredients(recipes.recipe_url[1], driver, ingredients)
#
# <ipython-input-14-07ef183c94c1> in scrape_ingredients(url, driver, ingredients)
#      35     ingredients_df['recipe_name'] = recipes.loc[recipes.recipe_url == url, 'recipe_name'].values[0]
#      36     ingredients_df['url'] = url
# ---> 37     ingredients = pd.concat([ingredients, ingredients_df])
#      38
#      39     return ingredients_df
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     293         verify_integrity=verify_integrity,
#     294         copy=copy,
# --> 295         sort=sort,
#     296     )
#     297
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     368                     "only Series and DataFrame objs are valid"
#     369                 )
# --> 370                 raise TypeError(msg)
#     371
#     372             # consolidate
#
# TypeError: cannot concatenate object of type '<class 'bs4.element.Tag'>'; only Series and DataFrame objs are valid

# %%
ingredients=ingredients.append(asdf)

# %%
asdf = pd.read_csv('ingredients.csv', index_col = ['recipe_num', 'ingredient_num'])

# %%
asdf
# Out:
#                            rating                            ingredient  \
# recipe_num ingredient_num
# 0          0                 4.74                      sprig fresh mint
#            1                 4.74                        bunch cilantro
#            2                 4.74             Italian flat leaf parsley
#            3                 4.74                             red onion
#            4                 4.74               large Pomegranates, raw
# ...                           ...                                   ...
# 1999       8                 3.88                                 water
#            9                 3.88                  (12 ounce) jar honey
#            10                3.88           (12 ounce) bottle olive oil
#            11                3.88  (.25 ounce) package active dry yeast
#            12                3.88                            pinch salt
#
#                            quantity                  unit
# recipe_num ingredient_num
# 0          0                    1.5                sprigs
#            1                    1.5               bunches
#            2                    1.5               bunches
#            3                    1.0                 small
#            4                    1.0                   NaN
# ...                             ...                   ...
# 1999       8                    4.0                  cups
#            9                    1.0                   cup
#            10                   0.5                   cup
#            11                   2.0  (.25 ounce) packages
#            12                   2.0           tablespoons
#
# [17342 rows x 4 columns]

# %%
ingredients
# Out:
#    rating                                    ingredient quantity         unit  \
# 0    4.73                         (1/2 pound) deer meat        1        pound
# 1    4.73                                     soy sauce        4  tablespoons
# 2    4.73  (10 fluid ounce) bottle Worcestershire sauce        4  tablespoons
# 3    4.73                                  liquid smoke        2  tablespoons
# 4    4.73                     (28 ounce) bottle ketchup        1   tablespoon
# 5    4.73                                  black pepper     0.25     teaspoon
# 6    4.73                           pinch garlic powder     0.25     teaspoon
# 7    4.73                                    onion salt     0.25     teaspoon
# 8    4.73                                    pinch salt      0.5     teaspoon
# 0    4.73                         (1/2 pound) deer meat        1        pound
# 1    4.73                                     soy sauce        4  tablespoons
# 2    4.73  (10 fluid ounce) bottle Worcestershire sauce        4  tablespoons
# 3    4.73                                  liquid smoke        2  tablespoons
# 4    4.73                     (28 ounce) bottle ketchup        1   tablespoon
# 5    4.73                                  black pepper     0.25     teaspoon
# 6    4.73                           pinch garlic powder     0.25     teaspoon
# 7    4.73                                    onion salt     0.25     teaspoon
# 8    4.73                                    pinch salt      0.5     teaspoon
#
#   recipe_name                                                url
# 0  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 1  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 2  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 3  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 4  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 5  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 6  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 7  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 8  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 0  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 1  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 2  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 3  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 4  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 5  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 6  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 7  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...
# 8  Deer Jerky  https://www.allrecipes.com//recipe/46324/deer-...

# %%
scrape_ingredients(recipes.recipe_url[1], driver)
# Out:
# C:\Users\Greg\anaconda3\envs\mlenv\lib\site-packages\bs4\element.py:447: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new_child.parent = self
# C:\Users\Greg\anaconda3\envs\mlenv\lib\site-packages\bs4\element.py:454: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new_child.previous_sibling = previous_child
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-275-4ef41e8d231c> in <module>
# ----> 1 scrape_ingredients(recipes.recipe_url[1], driver)
#
# <ipython-input-273-a081de76e421> in scrape_ingredients(url, driver)
#      36     ingredients_df['url'] = url
#      37
# ---> 38     ingredients = ingredients.append(ingredients_df)
#      39
#      40     return ingredients_df
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\element.py in append(self, tag)
#     493         :param tag: A PageElement.
#     494         """
# --> 495         self.insert(len(self.contents), tag)
#     496
#     497     def extend(self, tags):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\element.py in insert(self, position, new_child)
#     458             new_child.previous_element.next_element = new_child
#     459
# --> 460         new_childs_last_element = new_child._last_descendant(False)
#     461
#     462         if position >= len(self.contents):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute '_last_descendant'

# %%
ingredients.append(scrape_ingredients(recipes.recipe_url[1], driver))
# Out:
# C:\Users\Greg\anaconda3\envs\mlenv\lib\site-packages\bs4\element.py:447: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new_child.parent = self
# C:\Users\Greg\anaconda3\envs\mlenv\lib\site-packages\bs4\element.py:454: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new_child.previous_sibling = previous_child
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-267-894f87fb91f9> in <module>
# ----> 1 ingredients.append(scrape_ingredients(recipes.recipe_url[1], driver))
#
# <ipython-input-263-08bc1fa1a7bb> in scrape_ingredients(url, driver)
#      36     ingredients_df['url'] = url
#      37
# ---> 38     ingredients.append(ingredients_df)
#      39
#      40     return ingredients_df
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\element.py in append(self, tag)
#     493         :param tag: A PageElement.
#     494         """
# --> 495         self.insert(len(self.contents), tag)
#     496
#     497     def extend(self, tags):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\bs4\element.py in insert(self, position, new_child)
#     458             new_child.previous_element.next_element = new_child
#     459
# --> 460         new_childs_last_element = new_child._last_descendant(False)
#     461
#     462         if position >= len(self.contents):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute '_last_descendant'

# %%
ingredients = pd.DataFrame()

# %%
index = pd.MultiIndex.from_product([[0], np.arange(0)], names=['recipe_num', 'ingredient_num'])
ingredients = pd.DataFrame(columns=['rating', 'ingredient', 'quantity', 'unit'], index=index)

# Loop through all recipes and get ingredients
for i in range(2000):
    temp_ingredients = scrape_ingredients(recipes.recipe_url[i], driver)

    # Reindex as a multi index with the recipe as an indexer
    index = pd.MultiIndex.from_product([[i], np.arange(len(temp_ingredients))], names=['recipe_num', 'ingredient_num'])
    temp_ingredients = temp_ingredients.set_index(index)

    ingredients = pd.concat([ingredients, temp_ingredients])

# %%
def scrape(url):
    temp_ingredients = scrape_ingredients(url, driver)
    # Reindex as a multi index with the recipe as an indexer
    index = pd.MultiIndex.from_product([[url], np.arange(len(temp_ingredients))], names=['url', 'ingredient_num'])
    temp_ingredients = temp_ingredients.set_index(index)

    ingredients = pd.concat([ingredients, temp_ingredients])

# %%
urls = recipes.recipe_url[0:100]

# %%
with concurrent.futures.ProcessPoolExecutor() as executor:
    f = executor.map(scrape_ingredients)

# %%
ingredients.to_csv('ingredients.csv')

# %% [markdown]
# ## Filtering by ingredients

# %% [markdown]
# ## Prividing Recomendation
